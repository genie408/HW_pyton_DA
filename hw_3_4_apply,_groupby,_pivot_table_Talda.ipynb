# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_path = '/content/drive/MyDrive/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby ('Branch')['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
branches_tgi = df.groupby ('Branch')['gross income'].sum()
branches_tgi
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %%
print (f'Найприбутковішим філіалом є філіал {branches_tgi.idxmax()} його сумарний прибуток складає {branches_tgi.max()}')
# Out:
# Найприбутковішим філіалом є філіал C його сумарний прибуток складає 5265.1765

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df[df['Branch'] == 'C'] ['City'].head(1)
# Out:
# 1    Naypyitaw
# Name: City, dtype: object

# %% [markdown]
# Для прийняття рішення про відкриття ще одного магазину, на мою думку, маємо замало інформації. Варто напевно окрім наявного оцінити: населення, конкуренцію, вартість землі/оренди приміщення. Не знаю, скільки там коштує відкриття магазину, але дохід $5000 за три місяці здається надто малим, для ухвалення рішення про відкриття ще однієї філії.

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = pd.pivot_table (df, index='Branch', columns='Product line', values='Invoice ID', aggfunc='nunique')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category['Electronic accessories'].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# ### 1 питання
# Якій формі оплати віддають перевагу покупці у різних містах.

# %%
pd.pivot_table (df, index='City', columns='Payment', values='Total', aggfunc='sum')
# Out:
# Payment          Cash  Credit card    Ewallet
# City
# Mandalay   35339.4615   37344.8565  33513.354
# Naypyitaw  43085.8575   30327.4650  37155.384
# Yangon     33781.2510   33094.7505  39324.369

# %% [markdown]
# Як бачимо, розподіл по даному критерію теж більш-менш рівномірний. Лише у Naypyitaw люди явно віддають перевагу готівці. У місті Mandalay найчастіше використовують кредитні картки, а у місті Yangon переважаючим способом є електронний гаманець. Але можна зважити на те що електронний гаманець і кредитна карта це більш цифрові і безконтактні способи оплати. І сумано вони переважають над готівкою приблизно 2 до 1. Можна розмістити додаткові каси самообслуговування з оплатою цифровими способами - це дозволить підвищити сервіс, зручно і менше черг.

# %% [markdown]
# ### 2 питання
# Хто більше відвідує наші магазини, чоловіки чи жінки і що вони купують

# %%
pd.pivot_table (df, index=['City', 'Gender'], columns='Product line', values='Invoice ID', aggfunc='nunique')
# Out:
# Product line      Electronic accessories  Fashion accessories  \
# City      Gender
# Mandalay  Female                      28                   33
#           Male                        27                   29
# Naypyitaw Female                      28                   35
#           Male                        27                   30
# Yangon    Female                      28                   28
#           Male                        32                   23
#
# Product line      Food and beverages  Health and beauty  Home and lifestyle  \
# City      Gender
# Mandalay  Female                  29                 20                  22
#           Male                    21                 33                  28
# Naypyitaw Female                  38                 23                  25
#           Male                    28                 29                  20
# Yangon    Female                  23                 21                  32
# ...

# %% [markdown]
# Дана інформація дозволяє краще зрозуміти цільову аудиторію і пропрацювати в маркетинговому плані ті ділянки, які просідають. Наприклад, у всіх містах чоловіки купують товари з категорії Health and beauty частіше за жінок, хоча логічніше (на мою думку) щоб було навпаки.

# %% [markdown]
# ### 3 питання
# Яку частину продажів забезпечують нам постійні клієнти

# %%
df.groupby ('Customer type')['Total'].sum()
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %% [markdown]
# Постійні клієнти мають невелику перевагу над звичайними, це варто підтримувати і розширювати різноманітними акціями і програмами лояльності, також ці дії будучи широко розрекламованими можуть дозволити нам не тільки збільшити  надходження від постійних клієнтів, а й збільшити кількість цих самих постійних клієнтів.
